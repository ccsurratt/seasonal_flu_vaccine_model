# %%
import pandas as pd

# %%
X = pd.read_csv('training_features', index_col='respondent_id')

# %%
y = pd.read_csv('training_labels', index_col='respondent_id')['seasonal_vaccine']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.shape
# Out:
# (20030, 35)

# %%
X_train_numerical = X_train.select_dtypes(exclude=object)
X_train_categorical = X_train.select_dtypes(include=object).fillna('Missing')

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder()

ohe.fit(X_train_categorical)

X_train_categorical_ohe = ohe.transform(X_train_categorical).toarray()

ohe_df = pd.DataFrame(X_train_categorical_ohe, 
                      columns=ohe.get_feature_names(X_train_categorical.columns),
                     index=X_train_categorical.index)

ohe_df
# Out:
#                age_group_18 - 34 Years  age_group_35 - 44 Years  \
# respondent_id
# 25194                              1.0                      0.0
# 14006                              0.0                      0.0
# 11285                              0.0                      0.0
# 2900                               0.0                      0.0
# 19083                              1.0                      0.0
# ...                                ...                      ...
# 21575                              0.0                      0.0
# 5390                               0.0                      0.0
# 860                                0.0                      0.0
# 15795                              0.0                      1.0
# 23654                              1.0                      0.0
#
#                age_group_45 - 54 Years  age_group_55 - 64 Years  \
# respondent_id
# 25194                              0.0                      0.0
# 14006                              1.0                      0.0
# 11285                              1.0                      0.0
# 2900                               0.0                      1.0
# 19083                              0.0                      0.0
# ...                                ...                      ...
# 21575                              0.0                      1.0
# 5390                               0.0                      1.0
# 860                                0.0                      1.0
# 15795                              0.0                      0.0
# 23654                              0.0                      0.0
#
#                age_group_65+ Years  education_12 Years  education_< 12 Years  \
# respondent_id
# 25194                          0.0                 1.0                   0.0
# 14006                          0.0                 0.0                   0.0
# 11285                          0.0                 0.0                   0.0
# 2900                           0.0                 0.0                   0.0
# 19083                          0.0                 0.0                   0.0
# ...                            ...                 ...                   ...
# 21575                          0.0                 0.0                   0.0
# 5390                           0.0                 0.0                   0.0
# 860                            0.0                 1.0                   0.0
# 15795                          0.0                 0.0                   0.0
# 23654                          0.0                 1.0                   0.0
#
#                education_College Graduate  education_Missing  \
# respondent_id
# 25194                                 0.0                0.0
# 14006                                 0.0                0.0
# 11285                                 1.0                0.0
# 2900                                  1.0                0.0
# 19083                                 0.0                1.0
# ...                                   ...                ...
# 21575                                 0.0                0.0
# 5390                                  0.0                0.0
# 860                                   0.0                0.0
# 15795                                 1.0                0.0
# 23654                                 0.0                0.0
#
#                education_Some College  ...  employment_occupation_qxajmpny  \
# respondent_id                          ...
# 25194                             0.0  ...                             0.0
# 14006                             1.0  ...                             0.0
# 11285                             0.0  ...                             0.0
# 2900                              0.0  ...                             0.0
# 19083                             0.0  ...                             0.0
# ...                               ...  ...                             ...
# 21575                             1.0  ...                             0.0
# 5390                              1.0  ...                             0.0
# 860                               0.0  ...                             0.0
# 15795                             0.0  ...                             0.0
# 23654                             0.0  ...                             0.0
#
#                employment_occupation_rcertsgn  employment_occupation_tfqavkke  \
# respondent_id
# 25194                                     0.0                             0.0
# 14006                                     0.0                             0.0
# 11285                                     0.0                             0.0
# 2900                                      0.0                             0.0
# 19083                                     0.0                             0.0
# ...                                       ...                             ...
# 21575                                     0.0                             0.0
# 5390                                      0.0                             0.0
# 860                                       0.0                             0.0
# 15795                                     0.0                             0.0
# 23654                                     0.0                             0.0
#
#                employment_occupation_ukymxvdu  employment_occupation_uqqtjvyb  \
# respondent_id
# 25194                                     0.0                             0.0
# 14006                                     0.0                             0.0
# 11285                                     0.0                             0.0
# 2900                                      1.0                             0.0
# 19083                                     0.0                             0.0
# ...                                       ...                             ...
# 21575                                     0.0                             0.0
# 5390                                      0.0                             0.0
# 860                                       0.0                             0.0
# 15795                                     0.0                             0.0
# 23654                                     0.0                             1.0
#
#                employment_occupation_vlluhbov  employment_occupation_xgwztkwe  \
# respondent_id
# 25194                                     0.0                             0.0
# 14006                                     0.0                             0.0
# 11285                                     0.0                             0.0
# 2900                                      0.0                             0.0
# 19083                                     0.0                             0.0
# ...                                       ...                             ...
# 21575                                     0.0                             0.0
# 5390                                      0.0                             0.0
# 860                                       0.0                             0.0
# 15795                                     0.0                             0.0
# 23654                                     0.0                             0.0
#
#                employment_occupation_xqwwgdyp  employment_occupation_xtkaffoo  \
# respondent_id
# 25194                                     0.0                             0.0
# 14006                                     0.0                             0.0
# 11285                                     0.0                             0.0
# 2900                                      0.0                             0.0
# 19083                                     0.0                             0.0
# ...                                       ...                             ...
# 21575                                     0.0                             0.0
# 5390                                      0.0                             0.0
# 860                                       1.0                             0.0
# 15795                                     0.0                             0.0
# 23654                                     0.0                             0.0
#
#                employment_occupation_xzmlyyjv
# respondent_id
# 25194                                     0.0
# 14006                                     0.0
# 11285                                     0.0
# 2900                                      0.0
# 19083                                     0.0
# ...                                       ...
# 21575                                     0.0
# 5390                                      0.0
# 860                                       0.0
# 15795                                     0.0
# 23654                                     0.0
#
# [20030 rows x 89 columns]

# %%
X_train = pd.concat([X_train_numerical, ohe_df], axis=1)

# %%
X_train
# Out:
#                h1n1_concern  h1n1_knowledge  behavioral_antiviral_meds  \
# respondent_id
# 25194                   1.0             1.0                        0.0
# 14006                   2.0             1.0                        0.0
# 11285                   0.0             0.0                        0.0
# 2900                    1.0             1.0                        0.0
# 19083                   2.0             1.0                        1.0
# ...                     ...             ...                        ...
# 21575                   2.0             1.0                        0.0
# 5390                    1.0             1.0                        0.0
# 860                     2.0             1.0                        0.0
# 15795                   2.0             1.0                        0.0
# 23654                   3.0             1.0                        0.0
#
#                behavioral_avoidance  behavioral_face_mask  \
# respondent_id
# 25194                           0.0                   0.0
# 14006                           1.0                   0.0
# 11285                           0.0                   0.0
# 2900                            0.0                   0.0
# 19083                           1.0                   0.0
# ...                             ...                   ...
# 21575                           0.0                   0.0
# 5390                            0.0                   0.0
# 860                             1.0                   0.0
# 15795                           1.0                   0.0
# 23654                           0.0                   0.0
#
#                behavioral_wash_hands  behavioral_large_gatherings  \
# respondent_id
# 25194                            0.0                          0.0
# 14006                            1.0                          0.0
# 11285                            0.0                          0.0
# 2900                             0.0                          0.0
# 19083                            1.0                          1.0
# ...                              ...                          ...
# 21575                            1.0                          0.0
# 5390                             1.0                          0.0
# 860                              0.0                          0.0
# 15795                            1.0                          0.0
# 23654                            1.0                          0.0
#
#                behavioral_outside_home  behavioral_touch_face  \
# respondent_id
# 25194                              0.0                    0.0
# 14006                              0.0                    0.0
# 11285                              0.0                    0.0
# 2900                               0.0                    0.0
# 19083                              1.0                    1.0
# ...                                ...                    ...
# 21575                              0.0                    1.0
# 5390                               0.0                    1.0
# 860                                0.0                    1.0
# 15795                              0.0                    1.0
# 23654                              1.0                    1.0
#
#                doctor_recc_h1n1  ...  employment_occupation_qxajmpny  \
# respondent_id                    ...
# 25194                       NaN  ...                             0.0
# 14006                       0.0  ...                             0.0
# 11285                       0.0  ...                             0.0
# 2900                        0.0  ...                             0.0
# 19083                       1.0  ...                             0.0
# ...                         ...  ...                             ...
# 21575                       0.0  ...                             0.0
# 5390                        NaN  ...                             0.0
# 860                         0.0  ...                             0.0
# 15795                       1.0  ...                             0.0
# 23654                       0.0  ...                             0.0
#
#                employment_occupation_rcertsgn  employment_occupation_tfqavkke  \
# respondent_id
# 25194                                     0.0                             0.0
# 14006                                     0.0                             0.0
# 11285                                     0.0                             0.0
# 2900                                      0.0                             0.0
# 19083                                     0.0                             0.0
# ...                                       ...                             ...
# 21575                                     0.0                             0.0
# 5390                                      0.0                             0.0
# 860                                       0.0                             0.0
# 15795                                     0.0                             0.0
# 23654                                     0.0                             0.0
#
#                employment_occupation_ukymxvdu  employment_occupation_uqqtjvyb  \
# respondent_id
# 25194                                     0.0                             0.0
# 14006                                     0.0                             0.0
# 11285                                     0.0                             0.0
# 2900                                      1.0                             0.0
# 19083                                     0.0                             0.0
# ...                                       ...                             ...
# 21575                                     0.0                             0.0
# 5390                                      0.0                             0.0
# 860                                       0.0                             0.0
# 15795                                     0.0                             0.0
# 23654                                     0.0                             1.0
#
#                employment_occupation_vlluhbov  employment_occupation_xgwztkwe  \
# respondent_id
# 25194                                     0.0                             0.0
# 14006                                     0.0                             0.0
# 11285                                     0.0                             0.0
# 2900                                      0.0                             0.0
# 19083                                     0.0                             0.0
# ...                                       ...                             ...
# 21575                                     0.0                             0.0
# 5390                                      0.0                             0.0
# 860                                       0.0                             0.0
# 15795                                     0.0                             0.0
# 23654                                     0.0                             0.0
#
#                employment_occupation_xqwwgdyp  employment_occupation_xtkaffoo  \
# respondent_id
# 25194                                     0.0                             0.0
# 14006                                     0.0                             0.0
# 11285                                     0.0                             0.0
# 2900                                      0.0                             0.0
# 19083                                     0.0                             0.0
# ...                                       ...                             ...
# 21575                                     0.0                             0.0
# 5390                                      0.0                             0.0
# 860                                       1.0                             0.0
# 15795                                     0.0                             0.0
# 23654                                     0.0                             0.0
#
#                employment_occupation_xzmlyyjv
# respondent_id
# 25194                                     0.0
# 14006                                     0.0
# 11285                                     0.0
# 2900                                      0.0
# 19083                                     0.0
# ...                                       ...
# 21575                                     0.0
# 5390                                      0.0
# 860                                       0.0
# 15795                                     0.0
# 23654                                     0.0
#
# [20030 rows x 112 columns]

# %%
X_train.isna().sum()
# Out:
# h1n1_concern                       67
# h1n1_knowledge                     87
# behavioral_antiviral_meds          56
# behavioral_avoidance              157
# behavioral_face_mask               14
#                                  ...
# employment_occupation_vlluhbov      0
# employment_occupation_xgwztkwe      0
# employment_occupation_xqwwgdyp      0
# employment_occupation_xtkaffoo      0
# employment_occupation_xzmlyyjv      0
# Length: 112, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(random_state=42)
tree.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-4316aa658636> in <module>
#       2
#       3 tree = DecisionTreeClassifier(random_state=42)
# ----> 4 tree.fit(X_train, y_train)
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     154             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     155             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 156             X, y = self._validate_data(X, y,
#     157                                        validate_separately=(check_X_params,
#     158                                                             check_y_params))
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     427                 # :(
#     428                 check_X_params, check_y_params = validate_separately
# --> 429                 X = check_array(X, **check_X_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     642
#     643         if force_all_finite:
# --> 644             _assert_all_finite(array,
#     645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      94                 not allow_nan and not np.isfinite(X).all()):
#      95             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 96             raise ValueError(
#      97                     msg_err.format
#      98                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
from sklearn import tree
